# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/dayth/OneDrive/Escritorio/Proyectos/EDA + ML/data/processed/dataset_variables_finales.csv", encoding="utf-8", delimiter=",")
df.head()
# Out:
#         precio  matrícula particular pagado 2024  superficie_total  \
# 0  322633576.0                            6810.0             404.0
# 1  157180460.0                            4221.0             190.0
# 2  133544301.0                            3215.0             146.0
# 3  117786861.0                             769.0             145.0
# 4  153241100.0                            2732.0             172.0
#
#    simce 4to básico lectura 2022  superficie_construida  banos   longitud  \
# 0                          285.0                  275.0    3.0 -70.678398
# 1                          279.0                  127.0    2.0 -70.559425
# 2                          273.0                   61.0    2.0 -70.689872
# 3                          273.0                   82.0    2.0 -70.887450
# 4                          283.0                   82.0    4.0 -70.709209
#
#    simce 4to básico matemáticas 2022  distancia_metro    latitud  ...  \
# 0                              274.0      2554.229150 -33.345468  ...
# 1                              268.0      2324.734493 -33.563025  ...
# 2                              258.0     11151.846959 -33.641678  ...
# 3                              256.0     16662.321199 -33.613778  ...
# 4                              269.0      1948.472205 -33.360659  ...
#
#    ingreso_promedio  dormitorios  extranjeros 2025 (%)  \
# 0         720051.66          5.0                   6.4
# 1         538232.86          3.0                   3.6
# 2         488733.18          5.0                   5.4
# 3         591753.35          3.0                   3.0
# 4         549642.87          4.0                  13.0
#
#    pobreza multidimensional 2022 (%)  pobreza por ingresos 2022 (%)  \
# 0                               18.6                            4.3
# 1                               18.9                            5.0
# 2                               18.7                            6.0
# 3                               15.1                            7.3
# 4                               17.0                            5.2
#
#    hogares hacinados 2025 (%)  trabajadores_información_comunicaciones_2023  \
# 0                         8.8                                       16518.0
# 1                         7.2                                         658.0
# 2                         9.0                                         498.0
# 3                         8.1                                          93.0
# 4                         8.7                                         861.0
#
#    trabajadores_financieras_seguros_2023  matrícula subvencionada 2024  \
# 0                                 3273.0                        4724.0
# 1                                   75.0                       84429.0
# 2                                   88.0                       38599.0
# 3                                   19.0                       12798.0
# 4                                  367.0                       33726.0
#
#    empresas_otras_actividades_2023
# 0                            487.0
# 1                           1922.0
# 2                            843.0
# 3                            299.0
# 4                            660.0
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#              precio  matrícula particular pagado 2024  superficie_total  \
# count  4.508000e+03                       4508.000000       4508.000000
# mean   2.269951e+08                       5935.789264        239.190614
# std    1.695139e+08                       6537.635455        160.193480
# min    3.500000e+07                          0.000000         60.300000
# 25%    1.137960e+08                       1711.000000        130.000000
# 50%    1.608840e+08                       3670.000000        185.790000
# 75%    2.825280e+08                       6810.000000        300.000000
# max    8.993808e+08                      29882.000000        997.000000
#
#        simce 4to básico lectura 2022  superficie_construida        banos  \
# count                    4508.000000            4508.000000  4508.000000
# mean                      281.761757             124.119898     2.207853
# std                         9.870991              79.646358     1.079104
# min                       264.000000              41.000000     1.000000
# 25%                       275.000000              75.000000     1.000000
# 50%                       280.000000             100.000000     2.000000
# 75%                       284.000000             145.000000     3.000000
# max                       311.000000             921.000000     9.000000
#
#           longitud  simce 4to básico matemáticas 2022  distancia_metro  \
# count  4508.000000                        4508.000000      4508.000000
# mean    -70.664981                         268.336957      4884.006065
# std       0.104527                          11.124038      6933.394509
# min     -71.230881                         241.000000        13.830637
# 25%     -70.733557                         261.000000       930.801124
# 50%     -70.660684                         266.000000      2153.658847
# 75%     -70.579929                         269.000000      5532.063821
# max     -70.063234                         302.000000     53183.711028
#
#            latitud  ...  ingreso_promedio  dormitorios  extranjeros 2025 (%)  \
# count  4508.000000  ...      4.508000e+03  4508.000000           4508.000000
# mean    -33.490694  ...      7.109170e+05     3.646628              9.273425
# std       0.110347  ...      3.942604e+05     1.250523              7.692731
# min     -33.900865  ...      3.361606e+05     1.000000              1.500000
# 25%     -33.562059  ...      5.285481e+05     3.000000              4.800000
# 50%     -33.495793  ...      5.917533e+05     3.000000              6.800000
# 75%     -33.428590  ...      6.520742e+05     4.000000             10.700000
# max     -33.083891  ...      2.587578e+06    27.000000             41.400000
#
#        pobreza multidimensional 2022 (%)  pobreza por ingresos 2022 (%)  \
# count                        4508.000000                    4508.000000
# mean                           16.569321                       4.194099
# std                             5.546693                       1.595783
# min                             2.400000                       0.900000
# 25%                            13.500000                       3.300000
# 50%                            17.000000                       4.400000
# 75%                            19.300000                       5.100000
# max                            28.900000                       9.300000
#
#        hogares hacinados 2025 (%)  \
# count                 4508.000000
# mean                     7.557964
# std                      1.939147
# min                      1.800000
# 25%                      6.500000
# 50%                      8.200000
# 75%                      8.900000
# max                     12.900000
#
#        trabajadores_información_comunicaciones_2023  \
# count                                   4508.000000
# mean                                    4884.141970
# std                                    13088.142346
# min                                        4.000000
# 25%                                      333.000000
# 50%                                      842.000000
# 75%                                     2326.000000
# max                                    58742.000000
#
#        trabajadores_financieras_seguros_2023  matrícula subvencionada 2024  \
# count                            4508.000000                   4508.000000
# mean                             5561.675909                  32275.825865
# std                             19833.020755                  27461.263154
# min                                 1.000000                      0.000000
# 25%                                75.000000                  10597.000000
# 50%                               171.000000                  17548.000000
# 75%                               468.000000                  52545.000000
# max                             91650.000000                  84429.000000
#
#        empresas_otras_actividades_2023
# count                      4508.000000
# mean                       1287.143966
# std                        1264.901802
# min                          33.000000
# 25%                         473.000000
# 50%                         813.000000
# 75%                        1880.000000
# max                        5478.000000
#
# [8 rows x 21 columns]

# %%
print(df.columns.tolist())
# Out:
# ['precio', 'matrícula particular pagado 2024', 'superficie_total', 'simce 4to básico lectura 2022', 'superficie_construida', 'banos', 'longitud', 'simce 4to básico matemáticas 2022', 'distancia_metro', 'latitud', 'distancia_hospital', 'ingreso_promedio', 'dormitorios', 'extranjeros 2025 (%)', 'pobreza multidimensional 2022 (%)', 'pobreza por ingresos 2022 (%)', 'hogares hacinados 2025 (%)', 'trabajadores_información_comunicaciones_2023', 'trabajadores_financieras_seguros_2023', 'matrícula subvencionada 2024', 'empresas_otras_actividades_2023']

# %%
import matplotlib.pyplot as plt

df.hist(figsize=(15, 10), bins=30, edgecolor='black')
plt.suptitle('Histogramas de cada variable', fontsize=16)
plt.tight_layout()
plt.show()
