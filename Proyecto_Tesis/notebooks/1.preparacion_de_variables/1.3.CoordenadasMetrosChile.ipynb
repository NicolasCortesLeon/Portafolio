# %%
import geopandas as gpd

gdf = gpd.read_file("/Users/dayth/OneDrive/Escritorio/Proyectos/EDA + ML/data/external/shapefiles/Estaciones_actuales_Metro_de_Santiago/Estaciones_actuales_Metro_de_Santiago..shp")

print(gdf.columns)

print(gdf.head())
# Out:
# Index(['FID', 'objectid', 'id', 'especial', 'estacion', 'nombre', 'temporal',
#        'f1', 'tipo', 'linea', 'geometry'],
#       dtype='object')
#    FID  objectid id                 especial      estacion         nombre  \
# 0    1         1  1     EXISTENTE INTERMODAL     EXISTENTE      SAN PABLO
# 1    2         2  2                EXISTENTE     EXISTENTE        NEPTUNO
# 2    3         3  3     EXISTENTE INTERMODAL     EXISTENTE      PAJARITOS
# 3    4         4  4                EXISTENTE     EXISTENTE      LAS REJAS
# 4    5         5  5  CONSTRUCCION INTERMODAL  CONSTRUCCION  QUINTA NORMAL
#
#      temporal  f1            tipo    linea                           geometry
# 0  INTERMODAL   1  ESTACION METRO  Linea 1  POINT (-7872880.466 -3954412.207)
# 1        None   1  ESTACION METRO  Linea 1  POINT (-7872796.968 -3955445.235)
# 2  INTERMODAL   1  ESTACION METRO  Linea 1  POINT (-7871780.014 -3956231.613)
# 3        None   1  ESTACION METRO  Linea 1  POINT (-7871008.747 -3956153.139)
# 4  INTERMODAL   1  ESTACION METRO  Linea 5  POINT (-7868069.788 -3953899.199)

# %%
estaciones_existentes = gdf[gdf['estacion'] == 'EXISTENTE']

# %%
gdf_latlon = gdf.to_crs(epsg=4326)

gdf_latlon[['nombre', 'linea', 'geometry']]
# Out:
#                nombre    linea                     geometry
# 0           SAN PABLO  Linea 1  POINT (-70.72329 -33.44419)
# 1             NEPTUNO  Linea 1  POINT (-70.72254 -33.45193)
# 2           PAJARITOS  Linea 1   POINT (-70.7134 -33.45783)
# 3           LAS REJAS  Linea 1  POINT (-70.70647 -33.45724)
# 4       QUINTA NORMAL  Linea 5  POINT (-70.68007 -33.44034)
# ..                ...      ...                          ...
# 112          LO PRADO  Linea 5  POINT (-70.71574 -33.44311)
# 113  GRUTA DE LOURDES  Linea 5  POINT (-70.69119 -33.43809)
# 114        BLANQUEADO  Linea 5  POINT (-70.70718 -33.44144)
# 115          PUDAHUEL  Linea 5  POINT (-70.74065 -33.44473)
# 116         CERRILLOS  Linea 6  POINT (-70.69529 -33.48331)
#
# [117 rows x 3 columns]

# %%
import folium

gdf_latlon = gdf.to_crs(epsg=4326)

gdf_latlon['lon'] = gdf_latlon.geometry.x
gdf_latlon['lat'] = gdf_latlon.geometry.y

# %%
mapa = folium.Map(location=[-33.45, -70.65], zoom_start=12)

for _, row in gdf_latlon.iterrows():
    folium.Marker(
        location=[row['lat'], row['lon']],
        popup=f"{row['nombre']} ({row['linea']})",
        tooltip=row['nombre'],
        icon=folium.Icon(color='blue', icon='train', prefix='fa')
    ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d35499ad914a8271c31c73473841924a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d35499ad914a8271c31c73473841924a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d35499ad914a8271c31c73473841924a = L.map(
#                 &quot;map_d35499ad914a8271c31c73473841924a&quot;,
#                 {
#                     center: [-33.45, -70.65],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9fbbaa0defd4b06886b1e090e9d6213d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9fbbaa0defd4b06886b1e090e9d6213d.addTo(map_d35499ad914a8271c31c73473841924a);
#
#
#             var marker_8ce25c7829fb0be26378caa9fa9f7745 = L.marker(
#                 [-33.444189549309556, -70.72328852952384],
#                 {
# }
#             ).addTo(map_d35499ad914a8271c31c73473841924a);
#
#
#             var icon_5ed88d254251fa6634db9acbec049f00 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;train&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9e61e35314f993169048bdd53bf94eb1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e634e2101f84a07f49b13e031e371e15 = $(`&lt;div id=&quot;html_e634e2101f84a07f49b13e031e371e15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SAN PABLO (Linea 1)&lt;/div&gt;`)[0];
#                 popup_9e61e35314f993169048bdd53bf94eb1.setContent(html_e634e2101f84a07f49b13e031e371e15);
#
#
#
#         marker_8ce25c7829fb0be26378caa9fa9f7745.bindPopup(popup_9e61e35314f993169048bdd53bf94eb1)
#         ;
#
#
#
#
#             marker_8ce25c7829fb0be26378caa9fa9f7745.bindTooltip(
#                 `&lt;div&gt;
#                      SAN PABLO
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_8ce25c7829fb0be26378caa9fa9f7745.setIcon(icon_5ed88d254251fa6634db9acbec049f00);
#
#
#             var marker_64c71d81982d90b677b37abf6c4b8b9c = L.marker(
#                 [-33.451932518829146, -70.72253845358516],
#                 {
# }
#             ).addTo(map_d35499ad914a8271c31c73473841924a);
#
#
#             var icon_60b6cac952b1df44185cd6d07ebe90ff = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;train&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_7cbf0b4cf50f9865a10a6af19900cb95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_167af1bdc7b078aa24305d3dc2b03d36 = $(`&lt;div id=&quot;html_167af1bdc7b078aa24305d3dc2b03d36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NEPTUNO (Linea 1)&lt;/div&gt;`)[0];
#                 popup_7cbf0b4cf50f9865a10a6af19900cb95.setContent(html_167af1bdc7b078aa24305d3dc2b03d36);
#
#
#
#         marker_64c71d81982d90b677b37abf6c4b8b9c.bindPopup(popup_7cbf0b4cf50f9865a10a6af19900cb95)
#         ;
#
#
#
#
#             marker_64c71d81982d90b677b37abf6c4b8b9c.bindTooltip(
#                 `&lt;div&gt;
#                      NEPTUNO
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_64c71d81982d90b677b37abf6c4b8b9c.setIcon(icon_60b6cac952b1df44185cd6d07ebe90ff);
#
#
#             var marker_97bce479b7c3a4d2769f7cf50948d9e7 = L.marker(
#                 [-33.45782628363531, -70.71340300218576],
#                 {
# }
#             ).addTo(map_d35499ad914a8271c31c73473841924a);
#
#
#             var icon_ed8a4ea388f49cde9ce33cd6fb17ec30 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;train&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_6bb8dce662205f38f8beaac7d7af495e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ab743ccbdf87b7bfd55046997655312 = $(`&lt;div id=&quot;html_1ab743ccbdf87b7bfd55046997655312&quot; style=&quot;wi

# %%
import pandas as pd

gdf_latlon = gdf.to_crs(epsg=4326)
gdf_latlon['longitud_estacion_metro'] = gdf_latlon.geometry.x
gdf_latlon['latitud_estacion_metro'] = gdf_latlon.geometry.y

df_coords_metro = gdf_latlon[['latitud_estacion_metro', 'longitud_estacion_metro']].copy()

df_coords_metro
# Out:
#      latitud_estacion_metro  longitud_estacion_metro
# 0                -33.444190               -70.723289
# 1                -33.451933               -70.722538
# 2                -33.457826               -70.713403
# 3                -33.457238               -70.706475
# 4                -33.440344               -70.680073
# ..                      ...                      ...
# 112              -33.443111               -70.715740
# 113              -33.438088               -70.691187
# 114              -33.441442               -70.707181
# 115              -33.444733               -70.740649
# 116              -33.483309               -70.695292
#
# [117 rows x 2 columns]

# %%
df_coords_metro.to_csv("/Users/dayth/OneDrive/Escritorio/Proyectos/EDA + ML/coordenadasmetrohospitales/coordenadas_estaciones_metro.csv", index=False)
